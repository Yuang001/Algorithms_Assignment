# %%
import time
import matplotlib.pyplot as plt

# Define the function F(n) that you want to measure
def F(n):
    # Example: Compute the nth Fibonacci number as F(n)
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return F(n-1) + F(n-2)

# Measure execution time for F(1) to F(100)
n_values = list(range(1, 101))
execution_times = []

for n in n_values:
    start_time = time.time()
    result = F(n)
    end_time = time.time()
    execution_time = end_time - start_time
    execution_times.append(execution_time)
    
    # Print the execution time for each F(n) computation
    print(f"Computed F({n}) in {execution_time:.6f} seconds")

    # If the computation takes too long or crashes, you can stop early
    # For example, if n > 40:
    #     break

# Plotting the execution times
plt.figure(figsize=(10, 6))
plt.plot(n_values, execution_times, marker='o', linestyle='-')
plt.title('Execution Time of F(1) to F(100)')
plt.xlabel('n')
plt.ylabel('Execution Time (seconds)')
plt.grid(True)
plt.show()
# Out:
# Computed F(1) in 0.000000 seconds
# Computed F(2) in 0.000000 seconds
# Computed F(3) in 0.000000 seconds
# Computed F(4) in 0.000000 seconds
# Computed F(5) in 0.000000 seconds
# Computed F(6) in 0.000000 seconds
# Computed F(7) in 0.000000 seconds
# Computed F(8) in 0.000000 seconds
# Computed F(9) in 0.000000 seconds
# Computed F(10) in 0.000000 seconds
# Computed F(11) in 0.000000 seconds
# Computed F(12) in 0.000000 seconds
# Computed F(13) in 0.000000 seconds
# Computed F(14) in 0.000000 seconds
# Computed F(15) in 0.000000 seconds
# Computed F(16) in 0.000000 seconds
# Computed F(17) in 0.000000 seconds
# Computed F(18) in 0.000000 seconds
# Computed F(19) in 0.000000 seconds
# Computed F(20) in 0.000000 seconds
# Computed F(21) in 0.011452 seconds
# Computed F(22) in 0.004177 seconds
# Computed F(23) in 0.000824 seconds
# Computed F(24) in 0.015796 seconds
# Computed F(25) in 0.014996 seconds
# Computed F(26) in 0.026325 seconds
# Computed F(27) in 0.041696 seconds
# Computed F(28) in 0.064957 seconds
# Computed F(29) in 0.113042 seconds
# Computed F(30) in 0.180046 seconds
# Computed F(31) in 0.290794 seconds
# Computed F(32) in 0.439976 seconds
# Computed F(33) in 0.748626 seconds
# Computed F(34) in 1.206449 seconds
# Computed F(35) in 1.962945 seconds
# Computed F(36) in 3.230648 seconds
# Computed F(37) in 5.144176 seconds
# Computed F(38) in 8.434924 seconds
# Computed F(39) in 13.595435 seconds
# Computed F(40) in 22.070612 seconds
# Computed F(41) in 36.015627 seconds
# Computed F(42) in 58.587494 seconds
# Computed F(43) in 94.571321 seconds
# Computed F(44) in 151.607168 seconds
# Computed F(45) in 244.733742 seconds
# Computed F(46) in 400.508366 seconds
# Computed F(47) in 644.562868 seconds
# Computed F(48) in 1049.642051 seconds
# Computed F(49) in 1712.035692 seconds
# Computed F(50) in 2735.500035 seconds
# Computed F(51) in 4424.887753 seconds
# Computed F(52) in 7322.231171 seconds
# Computed F(53) in 11847.738003 seconds
# Computed F(54) in 19049.189846 seconds
